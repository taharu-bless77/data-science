# %% [markdown]
# ![image.png](attachment:6ca525c1-bfe7-48d1-a7b5-ab402e0d578e.png)

# %%
import numpy as np

# %%
a = np.array([1,3,5])
b = np.array([5,7,9])
print(a,b)
# Out:
# [1 3 5] [5 7 9]

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
print(a + b)
# Out:
# [ 6 10 14]

# %%
print(a*b)
# Out:
# [ 5 21 45]

# %%
print(len(a))
# Out:
# 3
