# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:045b8093-4df3-4bdb-a62d-cbd4c7e57c3f.png)

# %%
df1 = pd.DataFrame([[1,3,5],[5,7,9]])
print(df1)
# Out:
#    0  1  2
# 0  1  3  5
# 1  5  7  9

# %%
df1.columns = ['c1','c2','c3']
print(df1)
# Out:
#    c1  c2  c3
# 0   1   3   5
# 1   5   7   9

# %%
df1.index = ['r1','r2']
print(df1)
# Out:
#     c1  c2  c3
# r1   1   3   5
# r2   5   7   9

# %%
print(df1.to_numpy())
# Out:
# [[1 3 5]
#  [5 7 9]]

# %%
print(df1.shape)
# Out:
# (2, 3)
